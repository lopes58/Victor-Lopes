# %%
pip install requests geopandas pandas notebook
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#    --------- ------------------------------ 4.7/19.2 MB 26.1 MB/s eta 0:00:01
#    --------------------------- ------------ 13.1/19.2 MB 32.9 MB/s eta 0:00:01
#    ---------------------------------------  19.1/19.2 MB 34.6 MB/s eta 0:00:01
#    ---------------------------------------- 19.2/19.2 MB 30.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 6.3/6.3 MB 35.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 30.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script pyproj.exe is installed in 'C:\Users\victor.lopes\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
# ...

# %%
# run case_functions.py
from case_functions import main

if __name__ == "__main__":
    main()
# Out:
# ...
# Iniciando extração de dados de aerogeradores
# ...
#
# [ETAPA 1] Extraindo dados da API...
# Requisitando dados...
# Recebidos 1000 registros
# Resposta bruta salva em: outputs\raw_response.json
#
# [ETAPA 2] Processando dados com geopandas...
# Relatório de validação salvo em: outputs\validation_report.json
#   - pot_mw: 0 ausentes
#   - alt_total: 0 ausentes
#   - alt_torre: 0 ausentes
#   - diam_rotor: 0 ausentes
#   - data_atualizacao: 0 ausentes
#   - eol_versao_id: 0 ausentes
#   - nome_eol: 0 ausentes
#   - den_aeg: 0 ausentes
#   - x: 0 ausentes
#   - y: 0 ausentes
# GeoDataFrame criado com 1000 registros e 24 colunas.
#
# [ETAPA 3] Salvando dados em CSV...
# Dados salvos em: outputs\aerogeradores.csv
#
# ...
# PROCESSO CONCLUÍDO COM SUCESSO!
# ...
